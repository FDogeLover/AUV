# %%
from qr_recognizer import QRDictionaryRecognizer

recognizer = QRDictionaryRecognizer(
    mapping_file="qr_mapping.txt",
    src="/dev/video32",
    laser_pin=19,
    servo_channel=0,
    servo_batch_size=6,
    laser_duration=1.0,
)

recognizer.run()
# Out:
# QR_NUMBER: WAITING
# Recognized QR 24 (1 total)
# QR_NUMBER: WAITING
# Recognized QR 23 (2 total)
# QR_NUMBER: WAITING
# Recognized QR 22 (3 total)
# QR_NUMBER: WAITING
# Recognized QR 21 (4 total)
# QR_NUMBER: WAITING
# Recognized QR 20 (5 total)
# QR_NUMBER: WAITING
# Recognized QR 19 (6 total)
# Servo moved to 180 degrees after 6 QRs
# QR_NUMBER: WAITING
# Recognized QR 18 (7 total)
# QR_NUMBER: WAITING
# Recognized QR 17 (8 total)
# QR_NUMBER: WAITING
# Recognized QR 16 (9 total)
# QR_NUMBER: WAITING
# Recognized QR 15 (10 total)
# QR_NUMBER: WAITING
# Recognized QR 14 (11 total)
# QR_NUMBER: WAITING
# Recognized QR 13 (12 total)
# Servo moved to 0 degrees after 12 QRs
# QR_NUMBER: WAITING
# Recognized QR 12 (13 total)
# QR_NUMBER: WAITING
